# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.rcsetup as rcsetup
import seaborn as sns
from scipy import stats
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline
import csv
import random

housing = pd.read_csv("C:/Users/mjoy/Machine-Learning-Project/train.csv")
#full = pd.read_csv("AmesHousing.csv")

# %%
pd.__version__
# Out:
# '0.22.0'

# %%
housing.head()
housing.length = housing.YrSold - housing.YearBuilt 
housing.totalsq = housing.TotalBsmtSF + housing.GrLivArea
#length houses in someones possesion
# Out:
# C:\Users\mjoy\Anaconda2\envs\py36\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#
# C:\Users\mjoy\Anaconda2\envs\py36\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
housing.head()
missings = ["Alley", "BsmtQual","BsmtCond","BsmtExposure","BsmtFinType1", 
"BsmtFinType2", "FireplaceQu", "GarageType","GarageFinish","GarageQual",
"GarageCond", "PoolQC", "Fence","MiscFeature","GarageYrBlt"]
housing[missings] = housing[missings].fillna(value = "None")

# %%
housing.isnull().sum()
cols = housing.columns[housing.isnull().any()].tolist()
cols = cols[1:4]
housing = housing.dropna(axis = 0, how = "any", subset = cols)
#housing = housing.drop('Id', axis = 1)
#housing = pd.DataFrame(housing)
#Lot Frontage has 259 missing values
#GarageYrBlt has 81 each -> because the property doesn't have a Garage
#MasVnrType and MasVnrArea have 8 missing values each
#Electrical has one missing values=1) & housing]

# %%
from pandas.api.types import CategoricalDtype

#convert categorical ordinal columns
catcols = ['ExterQual', 'ExterCond', 'BsmtQual',"BsmtCond",
           "BsmtExposure", "HeatingQC",
          "KitchenQual", "FireplaceQu", "GarageType","GarageQual",
          "GarageCond","PoolQC"]
labels = CategoricalDtype(['Ex','Gd','TA','Fa','Po','None'], ordered =True)
housing[catcols] = housing[catcols].apply(lambda x: x.astype('category'))
housing[catcols] = housing[catcols].apply(lambda x: x.cat.codes)

# %%
housing_dumm = pd.get_dummies(housing)

# %%
housing_dumm
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# 5        6          50         85.0    14115            5            5
# 6        7          20         75.0    10084            8            5
# 7        8          60          NaN    10382            7            6
# 8        9          50         51.0     6120            7            5
# 9       10         190         50.0     7420            5            6
# 10      11          20         70.0    11200            5            5
# 11      12          60         85.0    11924            9            5
# 12      13          20          NaN    12968            5            6
# 13      14          20         91.0    10652            7            5
# 14      15          20          NaN    10920            6            5
# 15      16          45         51.0     6120            7            8
# 16      17          20          NaN    11241            6            7
# 17      18          90         72.0    10791            4            5
# 18      19          20         66.0    13695            5            5
# 19      20          20         70.0     7560            5            6
# 20      21          60        101.0    14215            8            5
# 21      22          45         57.0     7449            7            7
# 22      23          20         75.0     9742            8            5
# 23      24         120         44.0     4224            5            7
# 24      25          20          NaN     8246            5            8
# 25      26          20        110.0    14230            8            5
# 26      27          20         60.0     7200            5            7
# 27      28          20         98.0    11478            8            5
# 28      29          20         47.0    16321            5            6
# 29      30          30         60.0     6324            4            6
# ...    ...         ...          ...      ...          ...          ...
# 1430  1431          60         60.0    21930            5            5
# 1431  1432         120          NaN     4928            6            6
# 1432  1433          30         60.0    10800            4            6
# 1433  1434          60         93.0    10261            6            5
# 1434  1435          20         80.0    17400            5            5
# 1435  1436          20         80.0     8400            6            9
# 1436  1437          20         60.0     9000            4            6
# 1437  1438          20         96.0    12444            8            5
# 1438  1439          20         90.0     7407            6            7
# 1439  1440          60         80.0    11584            7            6
# 1440  1441          70         79.0    11526            6            7
# 1441  1442         120          NaN     4426            6            5
# 1442  1443          60         85.0    11003           10            5
# 1443  1444          30          NaN     8854            6            6
# 1444  1445          20         63.0     8500            7            5
# 1455                     0                     1                      0
# 1456                     0                     1                      0
# 1457                     0                     1                      0
# 1458                     0                     1                      0
# 1459                     0                     1                      0
#
# [1451 rows x 351 columns]

# %%
#histogram of sales prices
sns.distplot(housing['SalePrice']);
#we can see it is skewed to left so we need to normalize

# %%
sns.distplot(np.log(housing['SalePrice']))

# %%
sns.heatmap(housing.corr(), square = True)

# %%
#check for missing value
housing_filled.isnull().sum().sum()
# Out:
# 0

# %%
#look at MSSubClass against Price
fig = plt.figure()
sub1 = fig.add_subplot(111)
sub1.scatter(x = housing2.LotArea, y = housing2.SalePrice)
sub1.set_xlim(0, 80000)
# Out:
# (0, 80000)

# %%
#get rid of outliers by computing abs value of zscore and removing points more than 3 sd from mean
lot_price = housing2[["LotArea", "SalePrice"]]
lot_price = lot_price[(np.abs(stats.zscore(lot_price)) < 4).all(axis=1)]
plt.scatter(x = lot_price.LotArea, y = lot_price.SalePrice)
plt.show()

# %%
#merge outlier dataset w/ original dataset for new dataset w/ outliers
y = pd.merge(housing2, lot_price, how = "inner", on = ["LotArea","SalePrice"])
y = y[-y.duplicated()]

# %%
#take out outliers from boston data housing pdf
fig2 = plt.figure()
sub2 = fig2.add_subplot(111)
sub2.scatter(x = housing2.GrLivArea, y = housing2.SalePrice)
sub2.set_xlim(0, 8000)
# Out:
# (0, 8000)

# %%
lot_price2 = housing2[["GrLivArea", "SalePrice"]]
lot_price2 = lot_price2[(np.abs(stats.zscore(lot_price2)) < 4).all(axis=1)]
plt.scatter(x = lot_price2.SalePrice, y = lot_price2.GrLivArea)
plt.show()

# %%
#converting categorical to numeric w/ their one-hot representations
#norm = y[y.SaleCondition == 'Normal']

# %%
import fancyimpute
from fancyimpute import BiScaler, KNN, NuclearNormMinimization, SoftImpute

# %%
#impute missing values w/ KNN 
housing_y = housing_dumm.SalePrice
housing_x = housing_dumm.drop('SalePrice', axis = 1)
housing_filled = pd.DataFrame(KNN(k=3).complete(housing_x))
# Out:
# Imputing row 1/1451 with 0 missing, elapsed time: 4.260
# Imputing row 101/1451 with 1 missing, elapsed time: 4.262
# Imputing row 201/1451 with 0 missing, elapsed time: 4.263
# Imputing row 301/1451 with 0 missing, elapsed time: 4.264
# Imputing row 401/1451 with 0 missing, elapsed time: 4.266
# Imputing row 501/1451 with 0 missing, elapsed time: 4.267
# Imputing row 601/1451 with 0 missing, elapsed time: 4.268
# Imputing row 701/1451 with 0 missing, elapsed time: 4.269
# Imputing row 801/1451 with 0 missing, elapsed time: 4.270
# Imputing row 901/1451 with 0 missing, elapsed time: 4.271
# Imputing row 1001/1451 with 1 missing, elapsed time: 4.272
# Imputing row 1101/1451 with 0 missing, elapsed time: 4.273
# Imputing row 1201/1451 with 1 missing, elapsed time: 4.275
# Imputing row 1301/1451 with 0 missing, elapsed time: 4.276
# Imputing row 1401/1451 with 0 missing, elapsed time: 4.277

# %%
preprocessing.StandardScaler().fit(x_filled)
#x_train = x_train.fit_transform(x_filled)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-871a146e67ee> in <module>()
# ----> 1 preprocessing.StandardScaler().fit(x_filled)
#       2 #x_train = x_train.fit(x_filled)
#
# NameError: name 'preprocessing' is not defined
